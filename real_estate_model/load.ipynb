# %%
import pandas as pd
import joblib

# %%
# Load trained pipeline
model = joblib.load("real_estate_price_pipeline.pkl")
print("✅ Model loaded successfully!")
# Out:
# ✅ Model loaded successfully!

# %%
# New input (e.g., site size = 1800 sq ft, 3 km from city, 11 m road distance)
input_data = pd.DataFrame([[1800, 15, 11]], 
                          columns=["site_size_sqft", "city_range_km", "road_distance_m"])

# Predict
predicted_price = model.predict(input_data)
print("🏠 Predicted Total Price:", predicted_price[0])
# Out:
# 🏠 Predicted Total Price: 187772.3381727467
